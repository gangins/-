# %% [markdown]
# <a href="https://colab.research.google.com/github/gangins/-/blob/main/%EB%AC%B8%EC%A0%9C_4_~6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###팩토리얼은 '계승'

# %%
#연속한 숫자의 곱을 구하는 알고리즘
#입력 : n
#출력 : 1부터 n까지 연속한 숫자를 곱한값

# %%
def fact(n):
  f = 1
  for i in range(1, n + 1):
    f = f * i
  return f

print(fact(1))
print(fact(5))
print(fact(10))
# Out:
# 1
# 120
# 3628800

# %%
def hello():
  print("hello")
  hello()

hello()
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
# 연속한 숫자의 곱을 구하는 알고리즘
# 입력 : n
# 출력 : 1부터 n까지 연속한 숫자를 곱한값

def fact(n):
  if n<=1:
    return 1
  return n * fact(n-1)

print(fact(1))
print(fact(5))
print(fact(10))
# Out:
# 1
# 120
# 3628800

# %%
def sumn(n):
  if n == 0:
    return 0
    
  return sumn(n-1) + n


print(sumn(1))
print(sumn(100))
print(sumn(10))
# Out:
# 1
# 5050
# 55

# %%
def fact(a, n):
  if n==1:
    return a[0]

  max = fact(a,n-1)
  if max > a[n-1]:
   return max 
  else:
    return a[n-1]

v = [17, 92, 18, 33, 58, 7, 33, 42]
print(fact(v, len(v)))
# Out:
# 92

# %%
# 최대 공약수 구하기
#입력 : a,b
#출력 : a,b의 최대공약수

def gcd(a,b):
  i = min(a,b)
  while True:
    if a % i == 0 and  b % i == 0:
        return i
    i = i-1
print(gcd(1,5))
print(gcd(99,98))
print(gcd(891,345))
print(gcd(21,55))
# Out:
# 1
# 1
# 3
# 1

# %%
# 최대 공약수 구하기
#입력 : a,b
#출력 : a,b의 최대공약수

def gcd(a,b):
    if b == 0:
        return a
    return gcd(b, a%b)
print(gcd(1,5))
print(gcd(99,98))
print(gcd(891,345))
print(gcd(21,55))
# Out:
# 1
# 1
# 3
# 1

# %%
from IPython.core.interactiveshell import no_op
def pivo(n):
  if n <=1:
    return n
  
  return  pivo(n-2) +  pivo(n-1)

print(pivo(7))
print(pivo(3))
# Out:
# 13
# 2

# %%
#하노이의 탑
#입력:옮기려는 원반의 개수 n
# 옮긴 원반이 현재 있는 출발점 기둥 from_pos
# 원반을 옮길 도착점 기둥 to_pos
# 옮기는 과정에서 사용할 보조 기둥 aux_pos
# 출력: 원반을 옮기는 순서

def hannoi(n, from_pos, to_pos, aux_pos):
  if n == 1:
    print(from_pos, "->", to_pos)
    return

    # 원반 n-1개를 aux_pos로 이동(to_pos를 보조기둥으로)
  hannoi(n-1, from_pos, aux_pos, to_pos)
    #가장큰원반을 목적지로 이동
  print(from_pos, "->", to_pos)

    # aux_pos에 있는원반 n-1개를 목적지 이동(from_pos를 보조기둥으로)
  hannoi(n-1, aux_pos, to_pos, from_pos)
  
print("n = 1")
hannoi(1,1,3,2)
print("n = 2")
hannoi(2,1,3,2)
print("n = 3")
hannoi(3,1,3,2)
# Out:
# n = 1
# 1 -> 3
# n = 2
# 1 -> 2
# 1 -> 3
# 2 -> 3
# n = 3
# 1 -> 3
# 1 -> 2
# 3 -> 2
# 1 -> 3
# 2 -> 1
# 2 -> 3
# 1 -> 3
